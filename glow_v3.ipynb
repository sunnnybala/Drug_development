# %%
import torch

# %%
#assert torch.__version__.startswith('2.3') and 'cu121' in torch.__version__, "The Colab torch version has changed, you may need to edit the !pip install cell to install matching torch_geometric versions"

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import pickle
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

import rdkit
from rdkit.Chem import Descriptors
from rdkit.Chem import Lipinski
from rdkit import Chem
from rdkit.Chem import RDConfig
from rdkit.Chem import rdChemReactions
from rdkit.Chem import AllChem
from rdkit.Chem import Draw,BRICS,Recap
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import rdmolops
from rdkit.Chem.BRICS import BRICSDecompose
from rdkit import Chem
from rdkit import DataStructs
from rdkit.Chem.Fingerprints import FingerprintMols


from PIL import Image

import sys
import re
import tqdm
import os
import seaborn as sns
import matplotlib.pyplot as plt

sys.path.append(os.path.join(RDConfig.RDContribDir, 'SA_Score'))

with warnings.catch_warnings():
    warnings.filterwarnings("ignore",category=DeprecationWarning)
    import sascorer

# %%
df = pd.read_excel('D:\drug_modelling\Oxazolidinone.xlsx')
df.drop([0],inplace = True)
df.drop({'Unnamed: 0'},axis = 1, inplace = True)
df.rename({'Unnamed: 3':'MIC'},inplace=True,axis = 1)
df.dropna(inplace = True)
df['REWARD'] = 1/df['MIC']
df['PMIC']=np.log(df['MIC'])
df.reset_index(inplace = True,drop = True)
# df2.rename({'pMIC':'Reward'},axis = 1,inplace = True)

# %%
df.head(5)
# Out:
#                                                SMILE Compound    MIC  REWARD  \
# 0  NC1=CN=C(C=NN2CCN(C3=CC=C(N4C[C@H](CNC(C)=O)OC...       2a  10.00     0.1
# 1  CC1=NC=C([N+]([O-])=O)N1CC=NN2CCN(C3=CC=C(N4C[...       2b   1.00     1.0
# 2  CC1=NC=C([N+]([O-])=O)N1CC(C)=NN2CCN(C3=CC=C(N...       2c   1.00     1.0
# 3  O=C(C)NC[C@H](OC1=O)CN1C(C=C2F)=CC=C2N3CCN(/N=...       2d   0.25     4.0
# 4  O=C(C)NC[C@H](OC1=O)CN1C(C=C2F)=CC=C2N3CCN(/N=...       2e   0.25     4.0
#
#        PMIC
# 0  2.302585
# 1  0.000000
# 2  0.000000
# 3 -1.386294
# 4 -1.386294

# %%
def number_atoms(mol):
  mol2 = mol
  for i, atom in enumerate(mol2.GetAtoms()):
      # For each atom, set the property "molAtomMapNumber" to a custom number, let's say, the index of the atom in the molecule
      atom.SetProp("molAtomMapNumber", str(atom.GetIdx()))

  return mol2

def AromaticAtoms(mol):
    aromatic_atoms = [mol.GetAtomWithIdx(i).GetIsAromatic() for i in range(mol.GetNumAtoms())]
    aa_count = []
    for i in aromatic_atoms:
      if i==True:
        aa_count.append(1)
    sum_aa_count = sum(aa_count)
    return sum_aa_count

def calc_descriptors(df):
  mols = [Chem.MolFromSmiles(smi) for smi in df['SMILE']]
  desc_MolLogP = [Descriptors.MolLogP(mol) for mol in mols]
  desc_MolWt = [Descriptors.MolWt(mol) for mol in mols]
  desc_NumRotatableBonds = [Descriptors.NumRotatableBonds(mol) for mol in mols]
  desc_AromaticAtoms = [AromaticAtoms(mol) for mol in mols]
  df['MolLogP'] = desc_MolLogP
  df['MolWt'] = desc_MolWt
  df['NumRotatableBonds'] = desc_NumRotatableBonds
  df['AromaticAtoms'] = desc_AromaticAtoms
  return df

#To test what samples are generated once before or after the training
def test_model(model = None,num_samples = 16, sub_img_size = 500,mols_per_row = 4):
  trajs = algo.create_training_data_from_own_samples(model,num_samples)
  gen_mols = []
  valid_trajs=[]
  for traj in trajs:
    try:
      mol = ctx.graph_to_obj(traj['result'])
      Chem.SanitizeMol(mol)  # Validate the molecule
      gen_mols.append(mol)
      valid_trajs.append(traj)
    except Chem.AtomValenceException:
      print(f"Valence issue in: {traj['result']}")
    except Chem.KekulizeException:
      print(f"Kekulization issue in: {traj['result']}")
    except Exception as e:
      print(f"Error: {e}")
  
  #gen_mols = [ctx.graph_to_obj(x['result']) for x in trajs]
  gen_mols_smiles = [Chem.MolToSmiles(mol) for mol in gen_mols]
  return gen_mols_smiles,gen_mols,Chem.Draw.MolsToGridImage(gen_mols, molsPerRow=mols_per_row, subImgSize=(sub_img_size, sub_img_size))

# %%
df = calc_descriptors(df)

# %%
display(df)
# Out:
#                                                  SMILE Compound    MIC  \
# 0    NC1=CN=C(C=NN2CCN(C3=CC=C(N4C[C@H](CNC(C)=O)OC...       2a  10.00
# 1    CC1=NC=C([N+]([O-])=O)N1CC=NN2CCN(C3=CC=C(N4C[...       2b   1.00
# 2    CC1=NC=C([N+]([O-])=O)N1CC(C)=NN2CCN(C3=CC=C(N...       2c   1.00
# 3    O=C(C)NC[C@H](OC1=O)CN1C(C=C2F)=CC=C2N3CCN(/N=...       2d   0.25
# 4    O=C(C)NC[C@H](OC1=O)CN1C(C=C2F)=CC=C2N3CCN(/N=...       2e   0.25
# ..                                                 ...      ...    ...
# 228  S=C(NC1=CC=C(F)C=C1)NC2=CC=C(C[C@]3(C)NC(OC3)=...      53d  65.00
# 229  S=C(NC1=CC=C(I)C=C1)NC2=CC=C(C[C@]3(C)NC(OC3)=...      53e  65.00
# 230  S=C(NC1=CC=C(OC)C=C1)NC2=CC=C(C[C@]3(C)NC(OC3)...      53f  50.00
# 231  S=C(NC1=CC=C(C)C=C1)NC2=CC=C(C[C@]3(C)NC(OC3)=...      53g  65.00
# 232  S=C(NC1=CC=C([N+]([O-])=O)C=C1)NC2=CC=C(C[C@]3...      53h  65.00
#
#        REWARD      PMIC  MolLogP    MolWt  NumRotatableBonds  AromaticAtoms
# 0    0.100000  2.302585  0.75880  458.498                  6             11
# 1    1.000000  0.000000  1.50812  502.507                  8             11
# 2    1.000000  0.000000  1.89822  516.534                  8             11
# 3    4.000000 -1.386294  1.94430  474.449                  7             11
# 4    4.000000 -1.386294  2.41280  490.517                  7             11
# ..        ...       ...      ...      ...                ...            ...
# 228  0.015385  4.174387  3.67560  359.426                  4             12
# 229  0.015385  4.174387  4.14110  467.332                  4             12
# 230  0.020000  3.912023  3.54510  371.462                  5             12
# 231  0.015385  4.174387  3.84492  355.463                  4             12
# 232  0.015385  4.174387  3.44470  386.433                  5             12
#
# [233 rows x 9 columns]

# %%
def compute_properties(smiles):
    mol = Chem.MolFromSmiles(smiles)
    if mol is None:
        return [None] * 11  

    mol_weight = Descriptors.MolWt(mol)
    logp = Descriptors.MolLogP(mol)
    tpsa = Descriptors.TPSA(mol)
    num_h_donors = Lipinski.NumHDonors(mol)
    num_h_acceptors = Lipinski.NumHAcceptors(mol)
    
    
    return [mol_weight, logp, tpsa, num_h_donors, num_h_acceptors]


df[['Molecular_Weight', 'LogP', 'TPSA', 'Num_H_Donors', 'Num_H_Acceptors']] = df['SMILE'].apply(compute_properties).apply(pd.Series)

# %%
display(df)
# Out:
#                                                  SMILE Compound    MIC  \
# 0    NC1=CN=C(C=NN2CCN(C3=CC=C(N4C[C@H](CNC(C)=O)OC...       2a  10.00
# 1    CC1=NC=C([N+]([O-])=O)N1CC=NN2CCN(C3=CC=C(N4C[...       2b   1.00
# 2    CC1=NC=C([N+]([O-])=O)N1CC(C)=NN2CCN(C3=CC=C(N...       2c   1.00
# 3    O=C(C)NC[C@H](OC1=O)CN1C(C=C2F)=CC=C2N3CCN(/N=...       2d   0.25
# 4    O=C(C)NC[C@H](OC1=O)CN1C(C=C2F)=CC=C2N3CCN(/N=...       2e   0.25
# ..                                                 ...      ...    ...
# 228  S=C(NC1=CC=C(F)C=C1)NC2=CC=C(C[C@]3(C)NC(OC3)=...      53d  65.00
# 229  S=C(NC1=CC=C(I)C=C1)NC2=CC=C(C[C@]3(C)NC(OC3)=...      53e  65.00
# 230  S=C(NC1=CC=C(OC)C=C1)NC2=CC=C(C[C@]3(C)NC(OC3)...      53f  50.00
# 231  S=C(NC1=CC=C(C)C=C1)NC2=CC=C(C[C@]3(C)NC(OC3)=...      53g  65.00
# 232  S=C(NC1=CC=C([N+]([O-])=O)C=C1)NC2=CC=C(C[C@]3...      53h  65.00
#
#        REWARD      PMIC  MolLogP    MolWt  NumRotatableBonds  AromaticAtoms  \
# 0    0.100000  2.302585  0.75880  458.498                  6             11
# 1    1.000000  0.000000  1.50812  502.507                  8             11
# 2    1.000000  0.000000  1.89822  516.534                  8             11
# 3    4.000000 -1.386294  1.94430  474.449                  7             11
# 4    4.000000 -1.386294  2.41280  490.517                  7             11
# ..        ...       ...      ...      ...                ...            ...
# 228  0.015385  4.174387  3.67560  359.426                  4             12
# 229  0.015385  4.174387  4.14110  467.332                  4             12
# 230  0.020000  3.912023  3.54510  371.462                  5             12
# 231  0.015385  4.174387  3.84492  355.463                  4             12
# 232  0.015385  4.174387  3.44470  386.433                  5             12
#
#      Molecular_Weight     LogP    TPSA  Num_H_Donors  Num_H_Acceptors
# 0             458.498  0.75880  121.32           2.0              9.0
# 1             502.507  1.50812  138.44           1.0             10.0
# 2             516.534  1.89822  138.44           1.0             10.0
# 3             474.449  1.94430  133.76           1.0              9.0
# 4             490.517  2.41280  120.62           1.0              9.0
# ..                ...      ...     ...           ...              ...
# 228           359.426  3.67560   62.39           3.0              3.0
# 229           467.332  4.14110   62.39           3.0              3.0
# 230           371.462  3.54510   71.62           3.0              4.0
# 231           355.463  3.84492   62.39           3.0              3.0
# 232           386.433  3.44470  105.53           3.0              5.0
#
# [233 rows x 14 columns]

# %% [markdown]
# testing models for proper mic prediction.

# %%
plt.figure(figsize=(8, 6)) 
plt.hist(df['MIC'], bins=100, edgecolor='black', alpha=0.7)

plt.xlabel('MIC Value')
plt.ylabel('Frequency')
plt.title('Histogram of MIC Values')

plt.show()

# %%
df_filtered = df[df['MIC'] < 40]
mic_mean = df_filtered['MIC'].mean()
print(f"Mean of 'mic': {mic_mean}")

mse = np.mean((df_filtered['MIC'] - mic_mean) ** 2)
print(f"Mean Squared Error (MSE): {mse}")
# Out:
# Mean of 'mic': 4.097852941176471
# Mean Squared Error (MSE): 49.70064012543253

# %%
df = df_filtered

# %%
df['MOL'] = df['SMILE'].apply(Chem.MolFromSmiles)


fps = [FingerprintMols.FingerprintMol(mol, minPath=1, maxPath=7, fpSize=2048,
                                      bitsPerHash=2, useHs=True, tgtDensity=0.0, minSize=128)
       for mol in df['MOL']]

def calculate_mic_estimate(fp, fps, rewards):
    similarities = DataStructs.BulkTanimotoSimilarity(fp, fps)  
    mic_estimate = np.dot(np.array(similarities), np.array(rewards)) / len(similarities)  
    return mic_estimate


df['model1'] = [calculate_mic_estimate(fp, fps, df['MIC']) for fp in fps]


mse = np.mean((df['MIC'] - df['model1']) ** 2)

print("DataFrame with MIC estimates:")
display(df)
print(f"Mean Squared Error (MSE): {mse}")
# Out:
# DataFrame with MIC estimates:
#                                                  SMILE Compound     MIC  \
# 0    NC1=CN=C(C=NN2CCN(C3=CC=C(N4C[C@H](CNC(C)=O)OC...       2a  10.000
# 1    CC1=NC=C([N+]([O-])=O)N1CC=NN2CCN(C3=CC=C(N4C[...       2b   1.000
# 2    CC1=NC=C([N+]([O-])=O)N1CC(C)=NN2CCN(C3=CC=C(N...       2c   1.000
# 3    O=C(C)NC[C@H](OC1=O)CN1C(C=C2F)=CC=C2N3CCN(/N=...       2d   0.250
# 4    O=C(C)NC[C@H](OC1=O)CN1C(C=C2F)=CC=C2N3CCN(/N=...       2e   0.250
# ..                                                 ...      ...     ...
# 205  O=C1O[C@@H](CNC(C)=O)[C@H]2N1CC3=CC(C4=CC=C(C#...      47a   0.125
# 206  O=C1O[C@@H](CNC(C)=O)[C@H]2N1CC3=CC(N4CCOCC4)=...      47b  32.000
# 208  [H]/C(C1=CC=CC=C1)=N\C2=CC=C(CC(CO3)N(C4C(N(CC...       48   2.500
# 209  [H]/C(C1=CC=CC=C1)=N\C2=CC=C(CC(CO3)N(C4C(N(CC...       49   5.600
# 210  [H]/C(C1=CC=CC=C1)=N\C2=CC=C(CC(CO3)N(C4C(N(C5...       50   2.250
#
#        REWARD      PMIC  MolLogP    MolWt  NumRotatableBonds  AromaticAtoms  \
# 0    0.100000  2.302585  0.75880  458.498                  6             11
# 1    1.000000  0.000000  1.50812  502.507                  8             11
# 2    1.000000  0.000000  1.89822  516.534                  8             11
# 3    4.000000 -1.386294  1.94430  474.449                  7             11
# 4    4.000000 -1.386294  2.41280  490.517                  7             11
# ..        ...       ...      ...      ...                ...            ...
# 205  8.000000 -2.079442  2.74598  379.391                  3             12
# 206  0.031250  3.465736  1.04390  363.389                  3              6
# 208  0.400000  0.916291  6.46940  536.459                  8             18
# 209  0.178571  1.722767  5.17980  527.621                 10             18
# 210  0.444444  0.810930  5.95720  501.586                  7             24
#
#      Molecular_Weight     LogP    TPSA  Num_H_Donors  Num_H_Acceptors  \
# 0             458.498  0.75880  121.32           2.0              9.0
# 1             502.507  1.50812  138.44           1.0             10.0
# 2             516.534  1.89822  138.44           1.0             10.0
# 3             474.449  1.94430  133.76           1.0              9.0
# 4             490.517  2.41280  120.62           1.0              9.0
# ..                ...      ...     ...           ...              ...
# 205           379.391  2.74598   82.43           1.0              4.0
# 206           363.389  1.04390   71.11           1.0              5.0
# 208           536.459  6.46940   62.21           0.0              4.0
# 209           527.621  5.17980   80.67           0.0              6.0
# 210           501.586  5.95720   62.21           0.0              4.0
#
#                                                    MOL    model1
# 0    <rdkit.Chem.rdchem.Mol object at 0x0000018DEAB...  2.134635
# 1    <rdkit.Chem.rdchem.Mol object at 0x0000018DEAB...  2.154120
# 2    <rdkit.Chem.rdchem.Mol object at 0x0000018DEAB...  2.163625
# 3    <rdkit.Chem.rdchem.Mol object at 0x0000018DEAB...  2.123263
# 4    <rdkit.Chem.rdchem.Mol object at 0x0000018DEAB...  2.094301
# ..                                                 ...       ...
# 205  <rdkit.Chem.rdchem.Mol object at 0x0000018DEB1...  1.914345
# 206  <rdkit.Chem.rdchem.Mol object at 0x0000018DEB1...  2.023686
# 208  <rdkit.Chem.rdchem.Mol object at 0x0000018DEB1...  1.882084
# 209  <rdkit.Chem.rdchem.Mol object at 0x0000018DEB1...  1.917995
# 210  <rdkit.Chem.rdchem.Mol object at 0x0000018DEB1...  1.964522
#
# [204 rows x 16 columns]
# Mean Squared Error (MSE): 53.060350092445496

# %%
from rdkit.Chem import QED

df['QED'] = df['MOL'].apply(QED.qed)

print("DataFrame with QED values:")
display(df)
# Out:
# DataFrame with QED values:
#                                                  SMILE Compound     MIC  \
# 0    NC1=CN=C(C=NN2CCN(C3=CC=C(N4C[C@H](CNC(C)=O)OC...       2a  10.000
# 1    CC1=NC=C([N+]([O-])=O)N1CC=NN2CCN(C3=CC=C(N4C[...       2b   1.000
# 2    CC1=NC=C([N+]([O-])=O)N1CC(C)=NN2CCN(C3=CC=C(N...       2c   1.000
# 3    O=C(C)NC[C@H](OC1=O)CN1C(C=C2F)=CC=C2N3CCN(/N=...       2d   0.250
# 4    O=C(C)NC[C@H](OC1=O)CN1C(C=C2F)=CC=C2N3CCN(/N=...       2e   0.250
# ..                                                 ...      ...     ...
# 205  O=C1O[C@@H](CNC(C)=O)[C@H]2N1CC3=CC(C4=CC=C(C#...      47a   0.125
# 206  O=C1O[C@@H](CNC(C)=O)[C@H]2N1CC3=CC(N4CCOCC4)=...      47b  32.000
# 208  [H]/C(C1=CC=CC=C1)=N\C2=CC=C(CC(CO3)N(C4C(N(CC...       48   2.500
# 209  [H]/C(C1=CC=CC=C1)=N\C2=CC=C(CC(CO3)N(C4C(N(CC...       49   5.600
# 210  [H]/C(C1=CC=CC=C1)=N\C2=CC=C(CC(CO3)N(C4C(N(C5...       50   2.250
#
#        REWARD      PMIC  MolLogP    MolWt  NumRotatableBonds  AromaticAtoms  \
# 0    0.100000  2.302585  0.75880  458.498                  6             11
# 1    1.000000  0.000000  1.50812  502.507                  8             11
# 2    1.000000  0.000000  1.89822  516.534                  8             11
# 3    4.000000 -1.386294  1.94430  474.449                  7             11
# 4    4.000000 -1.386294  2.41280  490.517                  7             11
# ..        ...       ...      ...      ...                ...            ...
# 205  8.000000 -2.079442  2.74598  379.391                  3             12
# 206  0.031250  3.465736  1.04390  363.389                  3              6
# 208  0.400000  0.916291  6.46940  536.459                  8             18
# 209  0.178571  1.722767  5.17980  527.621                 10             18
# 210  0.444444  0.810930  5.95720  501.586                  7             24
#
#      Molecular_Weight     LogP    TPSA  Num_H_Donors  Num_H_Acceptors  \
# 0             458.498  0.75880  121.32           2.0              9.0
# 1             502.507  1.50812  138.44           1.0             10.0
# 2             516.534  1.89822  138.44           1.0             10.0
# 3             474.449  1.94430  133.76           1.0              9.0
# 4             490.517  2.41280  120.62           1.0              9.0
# ..                ...      ...     ...           ...              ...
# 205           379.391  2.74598   82.43           1.0              4.0
# 206           363.389  1.04390   71.11           1.0              5.0
# 208           536.459  6.46940   62.21           0.0              4.0
# 209           527.621  5.17980   80.67           0.0              6.0
# 210           501.586  5.95720   62.21           0.0              4.0
#
#                                                    MOL    model1       QED
# 0    <rdkit.Chem.rdchem.Mol object at 0x0000018DEAB...  2.134635  0.613175
# 1    <rdkit.Chem.rdchem.Mol object at 0x0000018DEAB...  2.154120  0.325669
# 2    <rdkit.Chem.rdchem.Mol object at 0x0000018DEAB...  2.163625  0.318960
# 3    <rdkit.Chem.rdchem.Mol object at 0x0000018DEAB...  2.123263  0.365653
# 4    <rdkit.Chem.rdchem.Mol object at 0x0000018DEAB...  2.094301  0.359460
# ..                                                 ...       ...       ...
# 205  <rdkit.Chem.rdchem.Mol object at 0x0000018DEB1...  1.914345  0.889026
# 206  <rdkit.Chem.rdchem.Mol object at 0x0000018DEB1...  2.023686  0.869103
# 208  <rdkit.Chem.rdchem.Mol object at 0x0000018DEB1...  1.882084  0.245004
# 209  <rdkit.Chem.rdchem.Mol object at 0x0000018DEB1...  1.917995  0.268154
# 210  <rdkit.Chem.rdchem.Mol object at 0x0000018DEB1...  1.964522  0.231997
#
# [204 rows x 17 columns]

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df['QED'], df['MIC'], alpha=0.6, color='b')
plt.title('Scatter Plot: QED vs MIC')
plt.xlabel('QED')
plt.ylabel('MIC')
plt.grid(True)
plt.show()

# %%
numeric_df = df.select_dtypes(include=['number'])

print(numeric_df.columns)
# Out:
# Index(['MIC', 'REWARD', 'PMIC', 'MolLogP', 'MolWt', 'NumRotatableBonds',
#        'AromaticAtoms', 'Molecular_Weight', 'LogP', 'TPSA', 'Num_H_Donors',
#        'Num_H_Acceptors', 'model1', 'QED'],
#       dtype='object')

# %%
correlation_matrix = numeric_df.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
#sns.pairplot(numeric_df)
#plt.show()

# %%
X = df[['MolLogP', 'MolWt', 'NumRotatableBonds',
       'AromaticAtoms', 'Molecular_Weight', 'LogP', 'TPSA', 'Num_H_Donors',
       'Num_H_Acceptors', 'QED']] 
y = df['MIC']  

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

poly = PolynomialFeatures(degree=2)
X_poly_train = poly.fit_transform(X_train)
X_poly_test = poly.transform(X_test)

model = LinearRegression()
model.fit(X_poly_train, y_train)
# Out:
# LinearRegression()

# %%
predictions = model.predict(X_poly_train)
print(predictions)
mse = np.mean((y_train - predictions) ** 2)
print(f"Mean Squared Error: {mse}")
# Out:
# [ 1.19080544  1.65672684  0.48342609  6.77906895  7.8886261   7.40751457
#   5.10544443  1.42184782  3.29659557 -3.83039951  3.57587957  1.40834618
#  12.87105751  9.02570963 13.19864893  1.85887098  1.54009104 10.268291
#   7.84939098 -2.50444365  3.56645441  7.3436594   8.4343648   0.7664957
#   8.50612068  0.98159647  0.86542654  6.63152266 -1.06558847 -0.3707099
#   7.597363    9.4916358   6.20430183  0.48342609  5.02979565 -3.64943314
#   2.55077362  2.72009039  0.43364954 -0.45292807  6.20430183  2.64662361
#   4.88373232 -2.00963116  4.88373184  4.10038614  1.10360956  7.68882608
#  -0.33685064 -0.57012558  1.56004667  1.8755703  -0.54946756  2.58557081
#   3.00881624  7.72860193  8.7956562   5.90329266  3.14774275 -2.5523777
#   6.86938     5.65716934  1.75297451  6.42226553  5.46114349  3.2067914
#   1.9801116  -1.71682739  4.90617943  4.366395    2.16725492  8.25193834
#   6.53853989  4.12885094  4.31767654  7.40751457  2.63752794 -2.3058238
#   4.15175581  5.0887475   3.92340326  0.49604082  8.90268326  1.23493433
#  24.41276312  4.366395    6.20430183  2.5507741   9.86070871  2.39451551
#  10.64851046  2.04154968  0.69371128  9.74709129  2.5507741   0.48342609
#   1.5968976   6.87765265  2.32278824 -1.95192099  6.18769932  0.11321497
#   2.19706774 21.68010807 -1.61286736 -0.04741955 11.36071634  2.95278549
#   2.6271553   6.17101669  7.40707684  3.01637697 10.01818085  7.41121721
#   4.44011164  1.00340748  2.23442984 -3.59287262  2.67235231  4.68769121
#   2.64613962 -2.61282301 -1.54806662 -2.33299971  4.88373184  2.32278824
#   4.9061799   4.11443758  2.47461796  5.22415876  8.64972019  5.10544443
#   3.76169491 -4.35633135  6.55304527  6.51994038  1.20542479  7.45586157
#   6.83950996 11.90404367  2.18609715  1.68383455]
# Mean Squared Error: 33.05729263776677

# %%
predictions = model.predict(X_poly_test)
print(predictions)
mse = np.mean((y_test - predictions) ** 2)
print(f"Mean Squared Error: {mse}")
# Out:
# [ 7.08450222e+00  9.79401541e+00  9.42354441e+00  3.20127773e+00
#   6.05310249e+00  1.24233313e+01  3.75582647e+00 -5.24312830e+00
#   2.70928144e+00  1.69968605e-01  2.22602606e+00 -1.13198328e+00
#   1.19225402e+01  2.46047815e+02  1.10189652e+01 -1.42093086e+00
#  -1.95192099e+00  3.20127773e+00  8.35105896e+00  4.41892815e+00
#   1.35990477e+00 -2.61344147e+00  8.33357382e+00  1.65672684e+00
#   3.00881624e+00 -1.95192099e+00  7.47745085e+00  8.78728533e+00
#   2.02837276e+00  7.83933496e+00  3.98653936e+00  2.80143261e+00
#   4.00468349e-01  1.30004549e+00  3.56645441e+00  4.31664896e+00
#   2.21591282e+00  7.46685028e+00  8.46295118e+00  8.64972019e+00
#   9.04216433e+00  5.20594120e+00  3.76446152e+00  1.62661791e+00
#   3.25279236e-01  4.11833763e-01  8.49685049e+00  3.38973904e+00
#  -4.63289499e+00  1.07854915e+01  3.23104572e+00  5.30878115e+00
#   6.59047318e+00  2.20531368e+00 -3.34776402e+00  9.02570963e+00
#  -2.77566147e+00  6.79919338e+00 -5.36921501e-01  2.99536562e+00
#   7.58294010e+00  4.69390726e+00]
# Mean Squared Error: 967.4193110535795

# %%
for idx in range(30):
    print("Compound Number:",idx)
    mol2 = Chem.MolFromSmiles(df['SMILE'].iloc[idx])
    mol = Chem.MolFromSmiles(df['SMILE'].iloc[idx])
    Chem.Draw.MolsToGridImage([number_atoms(mol2)],subImgSize = (700,250),molsPerRow = 1)
# Out:
# Compound Number: 0
# Compound Number: 1
# Compound Number: 2
# Compound Number: 3
# Compound Number: 4
# Compound Number: 5
# Compound Number: 6
# Compound Number: 7
# Compound Number: 8
# Compound Number: 9
# Compound Number: 10
# Compound Number: 11
# Compound Number: 12
# Compound Number: 13
# Compound Number: 14
# Compound Number: 15
# Compound Number: 16
# Compound Number: 17
# Compound Number: 18
# Compound Number: 19
# Compound Number: 20
# Compound Number: 21
# Compound Number: 22
# Compound Number: 23
# Compound Number: 24
# Compound Number: 25
# Compound Number: 26
# Compound Number: 27
# Compound Number: 28
# Compound Number: 29

# %%
df.head()
# Out:
#                                                SMILE Compound    MIC  REWARD  \
# 0  NC1=CN=C(C=NN2CCN(C3=CC=C(N4C[C@H](CNC(C)=O)OC...       2a  10.00     0.1
# 1  CC1=NC=C([N+]([O-])=O)N1CC=NN2CCN(C3=CC=C(N4C[...       2b   1.00     1.0
# 2  CC1=NC=C([N+]([O-])=O)N1CC(C)=NN2CCN(C3=CC=C(N...       2c   1.00     1.0
# 3  O=C(C)NC[C@H](OC1=O)CN1C(C=C2F)=CC=C2N3CCN(/N=...       2d   0.25     4.0
# 4  O=C(C)NC[C@H](OC1=O)CN1C(C=C2F)=CC=C2N3CCN(/N=...       2e   0.25     4.0
#
#        PMIC  MolLogP    MolWt  NumRotatableBonds  AromaticAtoms  \
# 0  2.302585  0.75880  458.498                  6             11
# 1  0.000000  1.50812  502.507                  8             11
# 2  0.000000  1.89822  516.534                  8             11
# 3 -1.386294  1.94430  474.449                  7             11
# 4 -1.386294  2.41280  490.517                  7             11
#
#    Molecular_Weight     LogP    TPSA  Num_H_Donors  Num_H_Acceptors  \
# 0           458.498  0.75880  121.32           2.0              9.0
# 1           502.507  1.50812  138.44           1.0             10.0
# 2           516.534  1.89822  138.44           1.0             10.0
# 3           474.449  1.94430  133.76           1.0              9.0
# 4           490.517  2.41280  120.62           1.0              9.0
#
#                                                  MOL    model1       QED
# 0  <rdkit.Chem.rdchem.Mol object at 0x0000018DEAB...  2.134635  0.613175
# 1  <rdkit.Chem.rdchem.Mol object at 0x0000018DEAB...  2.154120  0.325669
# 2  <rdkit.Chem.rdchem.Mol object at 0x0000018DEAB...  2.163625  0.318960
# 3  <rdkit.Chem.rdchem.Mol object at 0x0000018DEAB...  2.123263  0.365653
# 4  <rdkit.Chem.rdchem.Mol object at 0x0000018DEAB...  2.094301  0.359460

# %%
import chemprop
arguments = [
      '--test_path', '/dev/null',
      '--preds_path', '/dev/null',
      '--checkpoint_dir', 'chemprop_checkpoint'
  ]

args = chemprop.args.PredictArgs().parse_args(arguments)

model_objects = chemprop.train.load_model(args=args)
# Out:
# Failed to find the pandas get_adjustment() function to patch
# Failed to patch pandas - PandasTools will have limited functionality
# Loading training args
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "readout.1.weight".
# Loading pretrained parameter "readout.1.bias".
# Loading pretrained parameter "readout.4.weight".
# Loading pretrained parameter "readout.4.bias".

# %%
fps = [FingerprintMols.FingerprintMol(Chem.MolFromSmiles(x), minPath=1, maxPath=7, fpSize=2048,
                               bitsPerHash=2, useHs=True, tgtDensity=0.0,
                               minSize=128) for x in df['SMILE'][:30]]

def reward(mol):
  fp = FingerprintMols.FingerprintMol(mol, minPath=1, maxPath=7, fpSize=2048,
                               bitsPerHash=2, useHs=True, tgtDensity=0.0,
                               minSize=128)

  s = DataStructs.BulkTanimotoSimilarity(fp,fps)

  return (np.dot(np.array(s),np.array(df['REWARD'][:30]))/len(s))#*(np.exp(1/sascorer.calculateScore(mol)))

score_limit = 4.0
def reward_with_score(mol):
  #fp = FingerprintMols.FingerprintMol(mol, minPath=1, maxPath=7, fpSize=2048,
                               #bitsPerHash=2, useHs=True, tgtDensity=0.0,
                               #minSize=128)

  #s = DataStructs.BulkTanimotoSimilarity(fp,fps)
  smile = Chem.MolToSmiles(mol)
  
  smiles = [[smile]]
  preds = chemprop.train.make_predictions(args=args, smiles=smiles, model_objects=model_objects)
  prim_reward=preds[0][0]
  print("mic estimate",prim_reward)
  '''
  df = pd.DataFrame({'SMILES': [smile]})
  df.to_csv('input.csv', index=False)

  # Specify the path to the trained model
  model_path = 'chemprop_model_pca.pt'  # Update this path to your model file
  
  # Run chemprop predict using command line
  os.system(f"chemprop_predict --test_path input.csv --checkpoint_path {model_path} --preds_path chemprop_predictions.csv")

  # Read and display results
  if os.path.exists('chemprop_predictions.csv'):
      predictions = pd.read_csv('chemprop_predictions.csv') 
      print("\nResults:")
      print(predictions)
      print(predictions['pIC50'][0])
  else:
      print("Prediction failed to generate output file")
  mic_estimate = predictions['pIC50'][0]
  prim_reward = mic_estimate
  print("mic estimate",mic_estimate)'''
  #sa_score = sascorer.calculateScore(mol)
  prim_reward = 100/prim_reward
  print("primary reward," , prim_reward)
  #print("sa_score," , sa_score)

  #wt = Descriptors.MolWt(mol)
  
  #temp = np.exp((-1*sa_score))*100                                #removed the score limit on the sa csore as it didnt make much sense
  #print("sa factor ," , temp)
  #prim_reward *= temp
  #sa_score = 1
  #print("primary reward wuth sa score," , prim_reward)
  # if(sa_score < score_limit):
  #   score_limit = sa_score
  #temp = np.exp((abs(wt - 600)*-1)/(100))*0.01                   #the weight factor was disproportionately changing the reward function,(on a magnitude of 62 orders!!) so scaled it appropriately. 
  #print("weigt factor," , temp)
  #prim_reward *= temp
  #print("primary reward with wweigt and sa sccroe," , prim_reward)
  #print("log reward", np.log(prim_reward))
  #print("_________________________________________________________________________________________________________________")
  return prim_reward, 5
  # return (np.dot(np.array(s),np.array(df['REWARD'][:30]))/len(s))*(np.exp(1/sascorer.calculateScore(mol)))

# %% [markdown]
# changes since 25 oct
# 1)removed the score limit on the sa csore as it didnt make much sense
# 2)the weight factor was disproportionately changing the reward function,(on a magnitude of 62 orders!!) so scaled it appropriately.

# %%
import time

# %%
for i in range(5):
    start = time.time()
    print("molecule number, ", i)
    reward_with_score(Chem.MolFromSmiles(df['SMILE'].iloc[i]))
    end = time.time()
    print("time taken for prediction of one molecule",end-start)
# Out:
# molecule number,  0
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:04<00:00,  4.46s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:04
# mic estimate 6.029318973891103
# primary reward, 16.585621101327078
# time taken for prediction of one molecule 4.4687182903289795
# molecule number,  1
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:03<00:00,  3.87s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:04
# mic estimate 6.028618537070648
# primary reward, 16.587548106600018
# time taken for prediction of one molecule 3.877479076385498
# molecule number,  2
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:03<00:00,  3.88s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:04
# mic estimate 6.024613562876716
# primary reward, 16.59857498847621
# time taken for prediction of one molecule 3.8833401203155518
# molecule number,  3
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:04<00:00,  4.36s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:04
# mic estimate 6.724208535445709
# primary reward, 14.8716387174586
# time taken for prediction of one molecule 4.367538928985596
# molecule number,  4
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:04<00:00,  4.58s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:05
# mic estimate 6.634656682855656
# primary reward, 15.07236994770293
# time taken for prediction of one molecule 4.580829620361328

# %%
reward(Chem.MolFromSmiles(df['SMILE'].iloc[0]))
# Out:
# 0.7337891258513708

# %%
final_frags = []
atch_idx = []
idx = -1

# %%
idx -= 1

# %%
idx += 1
print("Compound Number:",idx)
mol2 = Chem.MolFromSmiles(df['SMILE'].iloc[idx])
mol = Chem.MolFromSmiles(df['SMILE'].iloc[idx])
Chem.Draw.MolsToGridImage([number_atoms(mol2)],subImgSize = (700,250),molsPerRow = 1)
# Out:
# Compound Number: -1

# %%
break_idx = [(19,20)] #the indices about which fragmentation should take place

# %%
mh = Chem.RWMol(Chem.AddHs(mol))
for x in break_idx:
  a1idx = x[0]
  a2idx = x[1]
  Chem.Kekulize(mh,clearAromaticFlags=True)
  mh.RemoveBond(a1idx,a2idx) #Removing those respective bonds
  # print(Chem.MolToSmiles(mh))

# %%
#After the frags have been split, there is a '.' between each of their smiles representation
frags = [Chem.MolFromSmiles(x) for x in Chem.MolToSmiles(mh).split('.')]
curr_frags = []
for x in frags:
  sm = Chem.MolToSmiles(x)
  if(sm not in final_frags):
    final_frags.append(sm)
    curr_frags.append(sm)
  else:
    pass
    # frags.remove(x)
try:
  im = Chem.Draw.MolsToGridImage(list(map(lambda x:number_atoms(Chem.MolFromSmiles(x)),curr_frags)),molsPerRow = 3,subImgSize = (300,300))
except:
  im = None
  print("Nothing to add")

# %%
im

# %%
final_frags.pop(-1)
# Out:
# 'c1ccccc1'

# %%
at_idx = [[5]]
for i in at_idx:
  atch_idx.append(i)
len(final_frags),len(atch_idx)
# Out:
# (1, 1)

# %%
'''valid_frags = [mol for mol in map(Chem.MolFromSmiles, final_frags) if mol is not None]

# Attempt to draw the valid molecules
from rdkit.Chem import Draw
img = Draw.MolsToGridImage(valid_frags, molsPerRow=3, subImgSize=(300, 300))
img.show()'''
# Out:
# 'valid_frags = [mol for mol in map(Chem.MolFromSmiles, final_frags) if mol is not None]\n\n# Attempt to draw the valid molecules\nfrom rdkit.Chem import Draw\nimg = Draw.MolsToGridImage(valid_frags, molsPerRow=3, subImgSize=(300, 300))\nimg.show()'

# %%
#Chem.Draw.MolsToGridImage(list(map(Chem.MolFromSmiles,final_frags)))

# %%
frags_list = [(x,y) for x,y in zip(final_frags,atch_idx)]

# %%
frags_list = [('C=O', [0]),
 ('F', [0]),
 ('C', [0, 0]),
 ('c1ccccc1', [0, 1, 3]),
 ('c1c[nH]cn1', [0, 1, 3]),
 ('O=C1NCCO1', [2, 4]),
 ('C=N', [0, 1]),
 ('N', [0, 0, 0]),
 ('C1CNCCN1', [0, 1, 2, 5]),
 ('O=[N+][O-]', [1]),
 ('c1ccoc1', [2, 4]),
 ('c1ccsc1', [2, 4]),
 ('Cl', [0]),
 ('O', [0, 0]),
 ('Br', [0]),
 ('c1cn[nH]c1', [3, 0]),
 ('c1ccncc1', [2, 4]),
 ('C1COCCN1', [5])]


df = pd.read_csv("big_fragments.csv")  # Replace with your file path
display(df)
big_frags = list(zip(df["Fragment_SMILES"], df["Attachment_Points"].apply(eval)))

print(big_frags)



bengio_frag = [
    ("Br", [0]),
    ("C", [0]),
    ("C#N", [0]),
    ("C1=CCCCC1", [0, 2, 3]),
    ("C1=CNC=CC1", [0, 2]),
    ("C1CC1", [0]),
    ("C1CCCC1", [0]),
    ("C1CCCCC1", [0, 1, 2, 3, 4, 5]),
    ("C1CCNC1", [0, 2, 3, 4]),
    ("C1CCNCC1", [0, 1, 3]),
    ("C1CCOC1", [0, 1, 2, 4]),
    ("C1CCOCC1", [0, 1, 2, 4, 5]),
    ("C1CNCCN1", [2, 5]),
    ("C1COCCN1", [5]),
    ("C1COCC[NH2+]1", [5]),
    ("C=C", [0, 1]),
    ("C=C(C)C", [0]),
    ("C=CC", [0, 1]),
    ("C=N", [0]),
    ("C=O", [0]),
    ("CC", [0, 1]),
    ("CC(C)C", [1]),
    ("CC(C)O", [1]),
    ("CC(N)=O", [2]),
    ("CC=O", [1]),
    ("CCC", [1]),
    ("CCO", [1]),
    ("CN", [0, 1]),
    ("CNC", [1]),
    ("CNC(C)=O", [0]),
    ("CNC=O", [0, 2]),
    ("CO", [0, 1]),
    ("CS", [0]),
    ("C[NH3+]", [0]),
    ("C[SH2+]", [1]),
    ("Cl", [0]),
    ("F", [0]),
    ("FC(F)F", [1]),
    ("I", [0]),
    ("N", [0]),
    ("N=CN", [1]),
    ("NC=O", [0, 1]),
    ("N[SH](=O)=O", [1]),
    ("O", [0]),
    ("O=CNO", [1]),
    ("O=CO", [1]),
    ("O=C[O-]", [1]),
    ("O=PO", [1]),
    ("O=P[O-]", [1]),
    ("O=S=O", [1]),
    ("O=[NH+][O-]", [1]),
    ("O=[PH](O)O", [1]),
    ("O=[PH]([O-])O", [1]),
    ("O=[SH](=O)O", [1]),
    ("O=[SH](=O)[O-]", [1]),
    ("O=c1[nH]cnc2[nH]cnc12", [3, 6]),
    ("O=c1[nH]cnc2c1NCCN2", [8, 3]),
    ("O=c1cc[nH]c(=O)[nH]1", [2, 4]),
    ("O=c1nc2[nH]c3ccccc3nc-2c(=O)[nH]1", [8, 4, 7]),
    ("O=c1nccc[nH]1", [3, 6]),
    ("S", [0]),
    ("c1cc[nH+]cc1", [1, 3]),
    ("c1cc[nH]c1", [0, 2]),
    ("c1ccc2[nH]ccc2c1", [6]),
    ("c1ccc2ccccc2c1", [0, 2]),
    ("c1ccccc1", [0, 1, 2, 3, 4, 5]),
    ("c1ccncc1", [0, 1, 2, 4, 5]),
    ("c1ccsc1", [2, 4]),
    ("c1cn[nH]c1", [0, 1, 3, 4]),
    ("c1cncnc1", [0, 1, 3, 5]),
    ("c1cscn1", [0, 3]),
    ("c1ncc2nc[nH]c2n1", [2, 6]),
]

other_frags = [
    ("CO", [1, 0]),
    ("O=c1[nH]cnc2[nH]cnc12", [3, 6]),
    ("S", [0, 0]),
    ("C1CNCCN1", [2, 5]),
    ("c1cc[nH+]cc1", [3, 1]),
    ("c1ccccc1", [0, 2]),
    ("C1CCCCC1", [0, 2]),
    ("CC(C)C", [1, 2]),
    ("C1CCOCC1", [0, 2]),
    ("c1cn[nH]c1", [4, 0]),
    ("C1CCNC1", [2, 0]),
    ("c1cncnc1", [0, 1]),
    ("O=c1nc2[nH]c3ccccc3nc-2c(=O)[nH]1", [8, 4]),
    ("c1ccncc1", [1, 0]),
    ("O=c1nccc[nH]1", [6, 3]),
1O[C@@H](C)[C@H](O)[C@@H](O[C@@H]2O[C@H](COC(=O)C=Cc4ccc(O)c-3c4)[C@@H](O)[C@H](O)[C@H]2O)[C@H]1O', [0]), ('c1c2c3ccc(Cl)c(c3n1C)-c1c(nn(C)c1C)CSCc1cc(n(C)n1)CSc1cc(c3ccccc3c1)OCCC2', [0]), ('c1cccc2[nH]c3ccccc3c12', [0]), ('CCCCCCCCCO', [0]), ('[C@@H]1OC=C(C(=O)O)[C@H]2C[C@H][C@H](C)[C@@H]12', [0, 8]), ('C(=O)CCCN', [0, 1]), ('S(=O)(=O)c1cnc2ccccc2c1', [0, 7, 11]), ('NC1=NC[C@H](C)N1', [0]), ('C12CNCC(C)(CNC1)C2=O', [0]), ('c1ccc(C=O)cc1', [0, 1, 6]), ('C(=O)C(CC#Cc1ccc2c(c1)[C@]1(C(=O)N2C=O)CC2C(=O)O[C@H][C@H]N2[C@@H]1)C=O', [0, 15, 17, 22, 23, 25, 26]), ('N1C(c2ccccc2)=N[C@H][C@@H]1', [0, 4, 6, 8, 9]), ('C(=O)C(O)[C@](O)(CC(C)C)C=O', [0, 9]), ('[N@@+]1(C)CCc2ccccc2[C@@H]1C', [0, 5, 6, 10]), ('CC[C@@H]C', [0, 1, 2]), ('[C@H]1SC[C@H]2NC(=O)N[C@H]21', [0]), ('C(CC(N)=O)C(=O)O', [0]), ('NC#N', [0]), ('C(=O)C(O)CCN', [0]), ('[C@H]1N[C@H](C#N)CC1', [0, 5]), ('c1c2ccoc2cc2oc(=O)ccc12', [0, 5]), ('N1CCO[C@H]2[C@H]CC[C@H]21', [0, 4]), ('c1ccc(N)cc1', [0, 4, 5]), ('[C@H]1CN[C@H]2CCCO[C@H]21', [0]), ('N1C[C@@H](C)[C@H]Oc2cc(C#CC(C)(C)O)ccc2S1(=O)=O', [0, 3]), ('N1CCCc2ccccc21', [0, 5]) ...

# %%
import torch
from gflownet.config import init_empty, Config
from gflownet.models.graph_transformer import GraphTransformerGFN
from gflownet.envs.graph_building_env import GraphBuildingEnv
from gflownet.envs.frag_mol_env import FragMolBuildingEnvContext
from gflownet.envs.mol_building_env import MolBuildingEnvContext #Using this to build graphs didn't work
from gflownet.algo.trajectory_balance import TrajectoryBalance
from gflownet.algo.graph_sampling import GraphSampler

# %%
if torch.cuda.is_available():
    print("cuda available")
    from gflownet.utils.misc import set_main_process_device
    dev = torch.device('cuda')
    set_main_process_device(dev)
else:
    print("cpu mode")
    dev = torch.device('cpu')
# Out:
# cpu mode

# %%
torch.manual_seed(1)  # For demonstration purposes
cfg = Config()
env = GraphBuildingEnv()
ctx = FragMolBuildingEnvContext(fragments = final_frags)
model = GraphTransformerGFN(ctx, cfg).to(dev)
model2 = GraphTransformerGFN(ctx, cfg).to(dev)
# with open('/content/Without_SA') as file:
#   model = pickle.load(file)
# with open('/content/With_SA') as file:
#   model2 = pickle.load(file)
opt = torch.optim.Adam(model.parameters(), 3e-4)
algo = TrajectoryBalance(env, ctx, cfg)

# %%
'''import logging
logger = logging.getLogger()
logger.filter()'''
# Out:
# 'import logging\nlogger = logging.getLogger()\nlogger.filter()'

# %%
import pickle
import math

# %%
'''with open('D:\drug_modelling\Without_SA.unknown', 'rb') as file:
    model = pickle.load(file)
with open('D:\drug_modelling\With_SA','rb') as file:
    model2 = pickle.load(file)'''
# Out:
# "with open('D:\\drug_modelling\\Without_SA.unknown', 'rb') as file:\n    model = pickle.load(file)\nwith open('D:\\drug_modelling\\With_SA','rb') as file:\n    model2 = pickle.load(file)"

# %%
opt = torch.optim.Adam(model.parameters(), 1e-3) 
opt2 = torch.optim.Adam(model2.parameters(), 3e-4)
try:
    from tqdm.notebook import tqdm
except:
    tdqm = lambda x: x
beta = 32
losses = []
avg_rewards = []
for i in tqdm(range(200)):
    start = time.time()
    with torch.no_grad():  # We don't need to compute gradients here, they will be later
        trajs = algo.create_training_data_from_own_samples(model2, 64)
        print("traj len",len(trajs))
        objs = [ctx.graph_to_obj(i['result']) for i in trajs]
        log_rewards = torch.tensor([reward_with_score(x)[0] for x in objs]).to(dev)
        avg_rewards.append((log_rewards / len(trajs)).mean().item())
    batch = algo.construct_batch(trajs, None, log_rewards).to(dev)
    loss, _ = algo.compute_batch_losses(model2, batch)
    loss.backward()
    opt2.step()
    opt2.zero_grad()

    losses.append(loss.item())
    end = time.time()
    print(start-end)
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# traj len 64
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:04<00:00,  4.66s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:05
# mic estimate 6.015135904103363
# primary reward, 16.62472828449025
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:04<00:00,  4.10s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:04
# mic estimate 5.993406250869503
# primary reward, 16.6850027871033
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:04<00:00,  4.04s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:04
# mic estimate 6.294362923113707
# primary reward, 15.887231356296153
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:04<00:00,  4.10s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:04
# mic estimate 6.014235926597144
# primary reward, 16.62721602884974
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:03<00:00,  3.88s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:04
# mic estimate 6.021289240517812
# primary reward, 16.607738975083734
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:03<00:00,  3.91s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:04
# mic estimate 5.81574256612309
# primary reward, 17.194708820590446
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:03<00:00,  3.83s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:04
# mic estimate 5.999353350040311
# primary reward, 16.66846311016638
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:03<00:00,  3.85s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:04
# mic estimate 6.064966772393736
# primary reward, 16.488136498154592
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:03<00:00,  3.84s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:04
# mic estimate 6.05016076849831
# primary reward, 16.528486403315966
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:03<00:00,  3.86s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:04
# mic estimate 6.515900262083386
# primary reward, 15.34707346303458
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:03<00:00,  3.84s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:04
# mic estimate 5.8651552000024285
# primary reward, 17.04984720608222
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:03<00:00,  3.81s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:04
# mic estimate 6.343536169860088
# primary reward, 15.764078161188381
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:03<00:00,  3.85s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:04
# mic estimate 5.961876460244834
# primary reward, 16.77324256328071
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:03<00:00,  3.86s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:04
# mic estimate 6.750090572722858
# primary reward, 14.814616029613052
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:03<00:00,  3.82s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:04
# mic estimate 6.0210178827517655
# primary reward, 16.608487459648156
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:03<00:00,  3.83s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:04
# mic estimate 6.013308348006523
# primary reward, 16.629780848199992
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:03<00:00,  3.82s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:04
# mic estimate 6.329811478095621
# primary reward, 15.798258817983923
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:03<00:00,  3.90s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:04
# mic estimate 6.357360347967931
# primary reward, 15.72979893014308
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:04<00:00,  4.46s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:04
# mic estimate 6.305140881146753
# primary reward, 15.86007384847084
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:04<00:00,  4.17s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:04
# mic estimate 6.020893968689323
# primary reward, 16.608829273532088
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:04<00:00,  4.78s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:05
# mic estimate 6.042125057029466
# primary reward, 16.55046842892784
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:04<00:00,  4.50s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:05
# mic estimate 6.022282598378036
# primary reward, 16.604999577225538
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:04<00:00,  4.27s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:04
# mic estimate 5.993483397172297
# primary reward, 16.684788022801502
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:04<00:00,  4.93s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:05
# mic estimate 5.993659642375434
# primary reward, 16.684297402040592
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:04<00:00,  4.68s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:05
# mic estimate 6.027891626230053
# primary reward, 16.589548419360305
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:04<00:00,  4.69s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:05
# mic estimate 6.01665866102217
# primary reward, 16.620520729858224
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:04<00:00,  4.26s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:04
# mic estimate 5.932504053997165
# primary reward, 16.856288523329813
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:03<00:00,  3.86s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:04
# mic estimate 5.968474934851301
# primary reward, 16.754698828686866
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:04<00:00,  4.04s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:04
# mic estimate 6.029191854960066
# primary reward, 16.5859707910493
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:04<00:00,  4.36s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:04
# mic estimate 5.997142005757242
# primary reward, 16.674609322907518
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:04<00:00,  4.30s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:04
# mic estimate 5.997241883305236
# primary reward, 16.67433162540501
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:04<00:00,  4.32s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:04
# mic estimate 6.010926736145674
# primary reward, 16.636369796135963
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:03<00:00,  3.90s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:04
# mic estimate 6.008302152833605
# primary reward, 16.643636996990658
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:03<00:00,  3.86s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:04
# mic estimate 5
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:03<00:00,  3.84s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:04
# mic estimate 6.028729500003318
# primary reward, 16.5872428013141
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:03<00:00,  3.85s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:04
# mic estimate 6.229252602122922
# primary reward, 16.053290239975198
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:03<00:00,  3.82s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:04
# mic estimate 6.165461092081459
# primary reward, 16.21938708338195
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:03<00:00,  3.84s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:04
# mic estimate 5.966099660787367
# primary reward, 16.76136935111182
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:03<00:00,  3.86s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:04
# mic estimate 6.01556113035653
# primary reward, 16.62355312048391
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:03<00:00,  3.86s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:04
# mic estimate 5.977688838017561
# primary reward, 16.72887343416222
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:03<00:00,  3.89s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:04
# mic estimate 6.138143544508464
# primary reward, 16.291570777856077
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:03<00:00,  3.93s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:04
# mic estimate 6.062750259695823
# primary reward, 16.494164482542473
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:03<00:00,  3.83s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:04
# mic estimate 6.490089634695177
# primary reward, 15.40810768859231
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:03<00:00,  3.83s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:04
# mic estimate 6.042177237706844
# primary reward, 16.55032549789163
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:03<00:00,  3.84s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:04
# mic estimate 6.086984076689782
# primary reward, 16.428497058658632
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:03<00:00,  3.85s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:04
# mic estimate 6.046144225556304
# primary reward, 16.539466521045323
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:03<00:00,  3.82s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:04
# mic estimate 6.006820924259725
# primary reward, 16.64774116973096
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:03<00:00,  3.84s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:04
# mic estimate 6.035297825523193
# primary reward, 16.569190600189
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:03<00:00,  3.85s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:04
# mic estimate 6.173265263079184
# primary reward, 16.19888272063667
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:03<00:00,  3.85s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:04
# mic estimate 5.994350577437594
# primary reward, 16.682374296957956
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:03<00:00,  3.93s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:04
# mic estimate 5.81574256612309
# primary reward, 17.194708820590446
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
# 100%|██████████| 1/1 [00:03<00:00,  3.92s/it]
# Saving predictions to /dev/null
# Elapsed time = 0:00:04
# mic estimate 6.012164069329543
# primary reward, 16.63294594872087
# Setting molecule featurization parameters to default.
# Loading data
# Validating SMILES
# Test size = 1
#   0%|          | 0/1 [00:03<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[50], line 16
#      14     print("traj len",len(trajs))
#      15     objs = [ctx.graph_to_obj(i['result']) for i in trajs]
# ---> 16     log_rewards = torch.tensor([reward_with_score(x)[0] for x in objs]).to(dev)
#      17     avg_rewards.append((log_rewards / len(trajs)).mean().item())
#      18 batch = algo.construct_batch(trajs, None, log_rewards).to(dev)
#
# Cell In[50], line 16, in <listcomp>(.0)
#      14     print("traj len",len(trajs))
#      15     objs = [ctx.graph_to_obj(i['result']) for i in trajs]
# ---> 16     log_rewards = torch.tensor([reward_with_score(x)[0] for x in objs]).to(dev)
#      17     avg_rewards.append((log_rewards / len(trajs)).mean().item())
#      18 batch = algo.construct_batch(trajs, None, log_rewards).to(dev)
#
# Cell In[27], line 24, in reward_with_score(mol)
#      21 smile = Chem.MolToSmiles(mol)
#      23 smiles = [[smile]]
# ---> 24 preds = chemprop.train.make_predictions(args=args, smiles=smiles, model_objects=model_objects)
#      25 prim_reward=preds[0][0]
#      26 print("mic estimate",prim_reward)
#
# File d:\drug_modelling\gflow_venv\lib\site-packages\chemprop\utils.py:591, in timeit.<locals>.timeit_decorator.<locals>.wrap(*args, **kwargs)
#     588 @wraps(func)
#     589 def wrap(*args, **kwargs) -> Any:
#     590     start_time = time()
# --> 591     result = func(*args, **kwargs)
#     592     delta = timedelta(seconds=round(time() - start_time))
#     593     info = logging.getLogger(logger_name).info if logger_name is not None else print
#
# File d:\drug_modelling\gflow_venv\lib\site-packages\chemprop\train\make_predictions.py:462, in make_predictions(args, smiles, model_objects, calibrator, return_invalid_smiles, return_index_dict, return_uncertainty)
#     460     unc = [None] * len(full_data)
#     461 else:
# --> 462     preds, unc = predict_and_save(
#     463         args=args,
#     464         train_args=train_args,
#     465         test_data=test_data,
#     466         task_names=task_names,
#     467         num_tasks=num_tasks,
#     468         test_data_loader=test_data_loader,
#     469         full_data=full_data,
#     470         full_to_valid_indices=full_to_valid_indices,
#     471         models=models,
#     472         scalers=scalers,
#     473         num_models=num_models,
#     474         calibrator=calibrator,
#     475         return_invalid_smiles=return_invalid_smiles,
#     476     )
#     478 if return_index_dict:
#     479     preds_dict = {}
#
# File d:\drug_modelling\gflow_venv\lib\site-packages\chemprop\train\make_predictions.py:160, in predict_and_save(args, train_args, test_data, task_names, num_tasks, test_data_loader, full_data, full_to_valid_indices, models, scalers, num_models, calibrator, return_invalid_smiles, save_results)
#     124 def predict_and_save(
#     125     args: PredictArgs,
#     126     train_args: TrainArgs,
#    (...)
#     138     save_results: bool = True,
#     139 ):
#     140     """
#     141     Function to predict with a model and save the predictions to file.
#     142
#    (...)
#     158     :return: A list of lists of target predictions.
#     159     """
# --> 160     estimator = UncertaintyEstimator(
#     161         test_data=test_data,
#     162         test_data_loader=test_data_loader,
#     163         uncertainty_method=args.uncertainty_method,
#     164         models=models,
#     165         scalers=scalers,
#     166         num_models=num_models,
#     167         dataset_type=args.dataset_type,
#     168         loss_function=args.loss_function,
#     169         uncertainty_dropout_p=args.uncertainty_dropout_p,
#     170         dropout_sampling_size=args.dropout_sampling_size,
#     171         individual_ensemble_predictions=args.individual_ensemble_predictions,
#     172         spectra_phase_mask=getattr(train_args, "spectra_phase_mask", None),
#     173     )
#     175     preds, unc = estimator.calculate_uncertainty(
#     176         calibrator=calibrator
#     177     )  # preds and unc are lists of shape(data,tasks)
#     179     if calibrator is not None and args.is_atom_bond_targets and args.calibration_method == "isotonic":
#
# File d:\drug_modelling\gflow_venv\lib\site-packages\chemprop\uncertainty\uncertainty_estimator.py:29, in UncertaintyEstimator.__init__(self, test_data, test_data_loader, models, scalers, num_models, uncertainty_method, dataset_type, loss_function, uncertainty_dropout_p, dropout_sampling_size, individual_ensemble_predictions, spectra_phase_mask)
#      12 def __init__(
#      13     self,
#      14     test_data: MoleculeDataset,
#    (...)
#      25     spectra_phase_mask: List[List[bool]],
#      26 ):
#      27     self.uncertainty_method = uncertainty_method
# ---> 29     self.predictor = build_uncertainty_predictor(
#      30         test_data=test_data,
#      31         test_data_loader=test_data_loader,
#      32         models=models,
#      33         scalers=scalers,
#      34         num_models=num_models,
#      35         uncertainty_method=uncertainty_method,
#      36         dataset_type=dataset_type,
#      37         loss_function=loss_function,
#      38         uncertainty_dropout_p=uncertainty_dropout_p,
#      39         dropout_sampling_size=dropout_sampling_size,
#      40         individual_ensemble_predictions=individual_ensemble_predictions,
#      41         spectra_phase_mask=spectra_phase_mask,
#      42     )
#      43     self.label = self.predictor.label
#
# File d:\drug_modelling\gflow_venv\lib\site-packages\chemprop\uncertainty\uncertainty_predictor.py:1291, in build_uncertainty_predictor(uncertainty_method, test_data, test_data_loader, models, scalers, num_models, dataset_type, loss_function, uncertainty_dropout_p, dropout_sampling_size, individual_ensemble_predictions, spectra_phase_mask)
#    1287     raise NotImplementedError(
#    1288         f"Uncertainty predictor type {uncertainty_method} is not currently supported. Avalable options are: {list(supported_predictors.keys())}"
#    1289     )
#    1290 else:
# -> 1291     predictor = predictor_class(
#    1292         test_data=test_data,
#    1293         test_data_loader=test_data_loader,
#    1294         models=models,
#    1295         scalers=scalers,
#    1296         num_models=num_models,
#    1297         dataset_type=dataset_type,
#    1298         loss_function=loss_function,
#    1299         uncertainty_dropout_p=uncertainty_dropout_p,
#    1300         dropout_sampling_size=dropout_sampling_size,
#    1301         individual_ensemble_predictions=individual_ensemble_predictions,
#    1302         spectra_phase_mask=spectra_phase_mask,
#    1303     )
#    1304 return predictor
#
# File d:\drug_modelling\gflow_venv\lib\site-packages\chemprop\uncertainty\uncertainty_predictor.py:52, in UncertaintyPredictor.__init__(self, test_data, test_data_loader, models, scalers, num_models, dataset_type, loss_function, uncertainty_dropout_p, dropout_sampling_size, individual_ensemble_predictions, spectra_phase_mask)
#      50 self.raise_argument_errors()
#      51 self.test_data_loader = test_data_loader
# ---> 52 self.calculate_predictions()
#
# File d:\drug_modelling\gflow_venv\lib\site-packages\chemprop\uncertainty\uncertainty_predictor.py:147, in NoUncertaintyPredictor.calculate_predictions(self)
#     142     if bond_descriptor_scaler is not None:
#     143         self.test_data.normalize_features(
#     144             bond_descriptor_scaler, scale_bond_descriptors=True
#     145         )
# --> 147 preds = predict(
#     148     model=model,
#     149     data_loader=self.test_data_loader,
#     150     scaler=scaler,
#     151     atom_bond_scaler=atom_bond_scaler,
#     152     return_unc_parameters=False,
#     153 )
#     154 if self.dataset_type == "spectra":
#     155     preds = normalize_spectra(
#     156         spectra=preds,
#     157         phase_features=self.test_data.phase_features(),
#     158         phase_mask=self.spectra_phase_mask,
#     159         excluded_sub_value=float("nan"),
#     160     )
#
# File d:\drug_modelling\gflow_venv\lib\site-packages\chemprop\train\predict.py:48, in predict(model, data_loader, disable_progress_bar, scaler, atom_bond_scaler, return_unc_parameters, dropout_prob)
#      44 preds = []
#      46 var, lambdas, alphas, betas = [], [], [], []  # only used if returning uncertainty parameters
# ---> 48 for batch in tqdm(data_loader, disable=disable_progress_bar, leave=False):
#      49     # Prepare batch
#      50     batch: MoleculeDataset
#      51     mol_batch = batch.batch_graph()
#
# File d:\drug_modelling\gflow_venv\lib\site-packages\tqdm\std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File d:\drug_modelling\gflow_venv\lib\site-packages\torch\utils\data\dataloader.py:630, in _BaseDataLoaderIter.__next__(self)
#     627 if self._sampler_iter is None:
#     628     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     629     self._reset()  # type: ignore[call-arg]
# --> 630 data = self._next_data()
#     631 self._num_yielded += 1
#     632 if self._dataset_kind == _DatasetKind.Iterable and \
#     633         self._IterableDataset_len_called is not None and \
#     634         self._num_yielded > self._IterableDataset_len_called:
#
# File d:\drug_modelling\gflow_venv\lib\site-packages\torch\utils\data\dataloader.py:1328, in _MultiProcessingDataLoaderIter._next_data(self)
#    1325     return self._process_data(data)
#    1327 assert not self._shutdown and self._tasks_outstanding > 0
# -> 1328 idx, data = self._get_data()
#    1329 self._tasks_outstanding -= 1
#    1330 if self._dataset_kind == _DatasetKind.Iterable:
#    1331     # Check for _IterableDatasetStopIteration
#
# File d:\drug_modelling\gflow_venv\lib\site-packages\torch\utils\data\dataloader.py:1294, in _MultiProcessingDataLoaderIter._get_data(self)
#    1290     # In this case, `self._data_queue` is a `queue.Queue`,. But we don't
#    1291     # need to call `.task_done()` because we don't use `.join()`.
#    1292 else:
#    1293     while True:
# -> 1294         success, data = self._try_get_data()
#    1295         if success:
#    1296             return data
#
# File d:\drug_modelling\gflow_venv\lib\site-packages\torch\utils\data\dataloader.py:1132, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1119 def _try_get_data(self, timeout=_utils.MP_STATUS_CHECK_INTERVAL):
#    1120     # Tries to fetch data from `self._data_queue` once for a given timeout.
#    1121     # This can also be used as inner loop of fetching without timeout, with
#    (...)
#    1129     # Returns a 2-tuple:
#    1130     #   (bool: whether successfully get data, any: data if successful else None)
#    1131     try:
# -> 1132         data = self._data_queue.get(timeout=timeout)
#    1133         return (True, data)
#    1134     except Exception as e:
#    1135         # At timeout and error, we manually check whether any worker has
#    1136         # failed. Note that this is the only mechanism for Windows to detect
#    1137         # worker failures.
#
# File ~\.pyenv\pyenv-win\versions\3.10.5\lib\multiprocessing\queues.py:113, in Queue.get(self, block, timeout)
#     111 if block:
#     112     timeout = deadline - time.monotonic()
# --> 113     if not self._poll(timeout):
#     114         raise Empty
#     115 elif not self._poll():
#
# File ~\.pyenv\pyenv-win\versions\3.10.5\lib\multiprocessing\connection.py:262, in _ConnectionBase.poll(self, timeout)
#     260 self._check_closed()
#     261 self._check_readable()
# --> 262 return self._poll(timeout)
#
# File ~\.pyenv\pyenv-win\versions\3.10.5\lib\multiprocessing\connection.py:335, in PipeConnection._poll(self, timeout)
#     332 if (self._got_empty_message or
#     333             _winapi.PeekNamedPipe(self._handle)[0] != 0):
#     334     return True
# --> 335 return bool(wait([self], timeout))
#
# File ~\.pyenv\pyenv-win\versions\3.10.5\lib\multiprocessing\connection.py:884, in wait(object_list, timeout)
#     881                 ready_objects.add(o)
#     882                 timeout = 0
# --> 884     ready_handles = _exhaustive_wait(waithandle_to_obj.keys(), timeout)
#     885 finally:
#     886     # request that overlapped reads stop
#     887     for ov in ov_list:
#
# File ~\.pyenv\pyenv-win\versions\3.10.5\lib\multiprocessing\connection.py:816, in _exhaustive_wait(handles, timeout)
#     814 ready = []
#     815 while L:
# --> 816     res = _winapi.WaitForMultipleObjects(L, False, timeout)
#     817     if res == WAIT_TIMEOUT:
#     818         break
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(10, 5))
plt.plot(losses, marker='o', linestyle='-', color='b', markersize=8, linewidth=2)

# Adding labels and title
plt.xlabel('Time (Epochs or Steps)', fontsize=14)
plt.ylabel('loss', fontsize=14)
plt.title('loss Progress Over Time', fontsize=16)

# Optional: Grid and legend
plt.grid(True)
plt.legend(['loss'], loc='upper left')

# Display the plot
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(avg_rewards, marker='o', linestyle='-', color='b', markersize=8, linewidth=2)

# Adding labels and title
plt.xlabel('Time (Epochs or Steps)', fontsize=14)
plt.ylabel('Reward', fontsize=14)
plt.title('Reward Progress Over Time', fontsize=16)

# Optional: Grid and legend
plt.grid(True)
plt.legend(['Reward'], loc='upper left')

# Display the plot
plt.show()

# %%
'''opt = torch.optim.Adam(model.parameters(), 1e-3)
opt2 = torch.optim.Adam(model2.parameters(), 3e-4)
try:
    from tqdm.notebook import tqdm
except:
    tdqm = lambda x: x
beta = 32
losses2 = []
avg_rewards2 = []
for i in tqdm(range(150)):
    with torch.no_grad():  # We don't need to compute gradients here, they will be later
        trajs = algo.create_training_data_from_own_samples(model2, 64)

        #objs = [ctx.graph_to_obj(i['result']) for i in trajs] gives problems with the bigger dataset

        objs = []
        valid_trajs=[]
        for traj in trajs:
            try:
                mol = ctx.graph_to_obj(traj['result'])
                Chem.SanitizeMol(mol)  # Validate the molecule
                objs.append(mol)
                valid_trajs.append(traj)
            except Chem.AtomValenceException:
                print(f"Valence issue in: {traj['result']}")
            except Chem.KekulizeException:
                print(f"Kekulization issue in: {traj['result']}")
            except Exception as e:
                print(f"Error: {e}")

        log_rewards = torch.tensor([reward_with_score(x)[0] for x in objs]).to(dev)
    avg_rewards2.append((log_rewards / beta).mean().item())
    trajs = valid_trajs
    batch = algo.construct_batch(trajs, None, log_rewards).to(dev)
    loss, _ = algo.compute_batch_losses(model2, batch)
    loss.backward()
    opt2.step()
    opt2.zero_grad()

    losses2.append(loss.item())'''
# Out:
# 'opt = torch.optim.Adam(model.parameters(), 1e-3)\nopt2 = torch.optim.Adam(model2.parameters(), 3e-4)\ntry:\n    from tqdm.notebook import tqdm\nexcept:\n    tdqm = lambda x: x\nbeta = 32\nlosses2 = []\navg_rewards2 = []\nfor i in tqdm(range(150)):\n    with torch.no_grad():  # We don\'t need to compute gradients here, they will be later\n        trajs = algo.create_training_data_from_own_samples(model2, 64)\n\n        #objs = [ctx.graph_to_obj(i[\'result\']) for i in trajs] gives problems with the bigger dataset\n\n        objs = []\n        valid_trajs=[]\n        for traj in trajs:\n            try:\n                mol = ctx.graph_to_obj(traj[\'result\'])\n                Chem.SanitizeMol(mol)  # Validate the molecule\n                objs.append(mol)\n                valid_trajs.append(traj)\n            except Chem.AtomValenceException:\n                print(f"Valence issue in: {traj[\'result\']}")\n            except Chem.KekulizeException:\n                print(f"Kekulization issue in: {traj[\'result\']}")\n            except Exception as e:\n                print(f"
 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5441170930862427, 1.5625, 1.5625, 1.5508677959442139, 1.5625, 1.550540566444397, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5427665710449219, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5415916442871094, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5507206916809082, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5625, 1.5427665710449219, 1.5625, 1.5625, 1.5625]

# %%
'''opt = torch.optim.Adam(model.parameters(), 1e-3)
opt2 = torch.optim.Adam(model2.parameters(), 3e-4)
try:
    from tqdm.notebook import tqdm
except:
    tdqm = lambda x: x
beta = 32
losses2 = []
avg_rewards2 = []
for i in tqdm(range(500)):
    with torch.no_grad():  # We don't need to compute gradients here, they will be later
        trajs = algo.create_training_data_from_own_samples(model, 64)

        #objs = [ctx.graph_to_obj(i['result']) for i in trajs]

        objs = []
        valid_trajs=[]
        for traj in trajs:
            try:
                mol = ctx.graph_to_obj(traj['result'])
                Chem.SanitizeMol(mol)  # Validate the molecule
                objs.append(mol)
                valid_trajs.append(traj)
            except Chem.AtomValenceException:
                print(f"Valence issue in: {traj['result']}")
            except Chem.KekulizeException:
                print(f"Kekulization issue in: {traj['result']}")
            except Exception as e:
                print(f"Error: {e}")
        log_rewards = torch.tensor([reward(x) for x in objs]).to(dev)
    trajs = valid_trajs
    batch = algo.construct_batch(trajs, None, log_rewards).to(dev)
    loss, _ = algo.compute_batch_losses(model, batch)
    loss.backward()
    opt.step()
    opt.zero_grad()

    losses2.append(loss.item())
    avg_rewards2.append((log_rewards / beta).exp().mean().item())'''
# Out:
# 'opt = torch.optim.Adam(model.parameters(), 1e-3)\nopt2 = torch.optim.Adam(model2.parameters(), 3e-4)\ntry:\n    from tqdm.notebook import tqdm\nexcept:\n    tdqm = lambda x: x\nbeta = 32\nlosses2 = []\navg_rewards2 = []\nfor i in tqdm(range(500)):\n    with torch.no_grad():  # We don\'t need to compute gradients here, they will be later\n        trajs = algo.create_training_data_from_own_samples(model, 64)\n\n        #objs = [ctx.graph_to_obj(i[\'result\']) for i in trajs]\n\n        objs = []\n        valid_trajs=[]\n        for traj in trajs:\n            try:\n                mol = ctx.graph_to_obj(traj[\'result\'])\n                Chem.SanitizeMol(mol)  # Validate the molecule\n                objs.append(mol)\n                valid_trajs.append(traj)\n            except Chem.AtomValenceException:\n                print(f"Valence issue in: {traj[\'result\']}")\n            except Chem.KekulizeException:\n                print(f"Kekulization issue in: {traj[\'result\']}")\n            except Exception as e:\n                print(f"Error: {e}")\n        log_rewards = torch.tensor([reward(x) for x in objs]).to(dev)\n    trajs = valid_trajs\n    batch = algo.construct_batch(trajs, None, log_rewards).to(dev)\n    loss, _ = algo.compute_batch_losses(model, batch)\n    loss.backward()\n    opt.step()\n    opt.zero_grad()\n\n    losses2.append(loss.item())\n    avg_rewards2.append((log_rewards / beta).exp().mean().item())'

# %%
print(avg_rewards2)
print(losses2)
# Out:
# []
# []

# %% [markdown]
# 1) reduce beta to low value while sampling.

# %%
'''for x in _:
  print(sascorer.calculateScore(x))'''
# Out:
# 'for x in _:\n  print(sascorer.calculateScore(x))'

# %%
gensmiles,genmoles,im = test_model(model = model2,mols_per_row=2)
im

# %%
avg_wt = []
avg_sa = []
avg_mic = []

for i in genmoles:
    print("molecule number, ", i)
    x = reward_with_score(i)
    avg_wt.append(x[2])
    avg_sa.append(x[1])
    avg_mic.append(x[3])
print("average sa score", np.average(avg_sa))
print("average weight", np.average(avg_wt))
print("averge mic", np.average(avg_mic))

sns.histplot(avg_sa, bins=8, kde=False)  # kde=True adds a density curve
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Sa score')
plt.show()

sns.histplot(avg_wt, bins=8, kde=False)  # kde=True adds a density curve
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Weight')
plt.show()

sns.histplot(avg_mic, bins=8, kde=False)  # kde=True adds a density curve
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('MIC')
plt.show()
# Out:
# molecule number,  <rdkit.Chem.rdchem.Mol object at 0x00000174AEDDCB30>
# primary reward, 100.0
# sa_score, 1.0
# log reward 4.605170185988092
# _________________________________________________________________________________________________________________
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[177], line 8
#       6 print("molecule number, ", i)
#       7 x = reward_with_score(i)
# ----> 8 avg_wt.append(x[2])
#       9 avg_sa.append(x[1])
#      10 avg_mic.append(x[3])
#
# IndexError: tuple index out of range

# %%
gensmiles2,genmoles2,im2 = test_model(model = model2,mols_per_row=2)
im2

# %%
for i in genmoles2:
    print("molecule number, ", i)
    reward_with_score(i)
# Out:
# molecule number,  <rdkit.Chem.rdchem.Mol object at 0x0000017505BB61F0>
# primary reward, 79.20031190157736
# sa_score, 1.2626212902326763
# log reward 4.371980236963855
# _________________________________________________________________________________________________________________
# molecule number,  <rdkit.Chem.rdchem.Mol object at 0x0000017505BB6650>
# primary reward, 79.20031190157736
# sa_score, 1.2626212902326763
# log reward 4.371980236963855
# _________________________________________________________________________________________________________________
# molecule number,  <rdkit.Chem.rdchem.Mol object at 0x0000017505BB77D0>
# primary reward, 79.20031190157736
# sa_score, 1.2626212902326763
# log reward 4.371980236963855
# _________________________________________________________________________________________________________________
# molecule number,  <rdkit.Chem.rdchem.Mol object at 0x0000017505BB7290>
# primary reward, 79.20031190157736
# sa_score, 1.2626212902326763
# log reward 4.371980236963855
# _________________________________________________________________________________________________________________
# molecule number,  <rdkit.Chem.rdchem.Mol object at 0x0000017505BB7B50>
# primary reward, 79.20031190157736
# sa_score, 1.2626212902326763
# log reward 4.371980236963855
# _________________________________________________________________________________________________________________
# molecule number,  <rdkit.Chem.rdchem.Mol object at 0x0000017505BB7A00>
# primary reward, 79.20031190157736
# sa_score, 1.2626212902326763
# log reward 4.371980236963855
# _________________________________________________________________________________________________________________
# molecule number,  <rdkit.Chem.rdchem.Mol object at 0x0000017505BB7610>
# primary reward, 79.20031190157736
# sa_score, 1.2626212902326763
# log reward 4.371980236963855
# _________________________________________________________________________________________________________________
# molecule number,  <rdkit.Chem.rdchem.Mol object at 0x0000017505BB6490>
# primary reward, 79.20031190157736
# sa_score, 1.2626212902326763
# log reward 4.371980236963855
# _________________________________________________________________________________________________________________
# molecule number,  <rdkit.Chem.rdchem.Mol object at 0x0000017505BB5D90>
# primary reward, 79.20031190157736
# sa_score, 1.2626212902326763
# log reward 4.371980236963855
# _________________________________________________________________________________________________________________
# molecule number,  <rdkit.Chem.rdchem.Mol object at 0x0000017505BB5150>
# primary reward, 76.45343807568719
# sa_score, 1.3079856513581802
# log reward 4.336681902922902
# _________________________________________________________________________________________________________________
# molecule number,  <rdkit.Chem.rdchem.Mol object at 0x0000017505BB6D50>
# primary reward, 79.20031190157736
# sa_score, 1.2626212902326763
# log reward 4.371980236963855
# _________________________________________________________________________________________________________________
# molecule number,  <rdkit.Chem.rdchem.Mol object at 0x0000017505BB7300>
# primary reward, 79.20031190157736
# sa_score, 1.2626212902326763
# log reward 4.371980236963855
# _________________________________________________________________________________________________________________
# molecule number,  <rdkit.Chem.rdchem.Mol object at 0x00000174BFEDE570>
# primary reward, 79.20031190157736
# sa_score, 1.2626212902326763
# log reward 4.371980236963855
# _________________________________________________________________________________________________________________
# molecule number,  <rdkit.Chem.rdchem.Mol object at 0x00000174BFEDFD80>
# primary reward, 79.20031190157736
# sa_score, 1.2626212902326763
# log reward 4.371980236963855
# _________________________________________________________________________________________________________________
# molecule number,  <rdkit.Chem.rdchem.Mol object at 0x00000174BFEDEC00>
# primary reward, 79.20031190157736
# sa_score, 1.2626212902326763
# log reward 4.371980236963855
# _________________________________________________________________________________________________________________
# molecule number,  <rdkit.Chem.rdchem.Mol object at 0x00000174BFEDE340>
# primary reward, 79.20031190157736
# sa_score, 1.2626212902326763
# log reward 4.371980236963855
# _________________________________________________________________________________________________________________

# %%
from rdkit.Chem import SDMolSupplier

# Initialize an empty list to store the molecules
molecule_list = []

# Read the molecules from the SDF file
supplier = SDMolSupplier(".\\generated\\generated_molecules_small_frags_rachana.sdf")

# Iterate through the molecules and add them to the list if they are valid
for mol in supplier:
    if mol is not None:  # Ensure molecule is valid
        molecule_list.append(mol)

# Check the first few molecules to confirm
print(f"Number of molecules read: {len(molecule_list)}")
print(molecule_list[:5])  # Display the first 5 molecules in the list


for i in molecule_list:
    print("molecule number, ", i)
    reward_with_score(i)

# %%
with open(".\generated\generated_molecules_small_frags_rachana.txt", "w") as f:
    for smile in gensmiles:
        f.write(smile + "\n")
from rdkit.Chem import SDWriter

with SDWriter(".\generated\generated_molecules_small_frags_rachana.sdf") as writer:
    for mol in genmoles:
        if mol is not None:  # Ensure molecule is valid
            writer.write(mol)

with open(".\generated\generated_molecules_small_frags_rachana.png", "wb") as f:
    f.write(im.data)

# %%
with open(".\generated\generated_smiles2_weight_sascaled.txt", "w") as f:
    for smile in gensmiles2:
        f.write(smile + "\n")
from rdkit.Chem import SDWriter

with SDWriter(".\generated\generated_molecules2_weight_sascaled.sdf") as writer:
    for mol in genmoles2:
        if mol is not None:  # Ensure molecule is valid
            writer.write(mol)

with open(".\generated\generated_images2_weight_sascaled.png", "wb") as f:
    f.write(im2.data)
